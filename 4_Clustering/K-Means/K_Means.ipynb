# %% [markdown]
# <a href="https://colab.research.google.com/github/Icy-Bear/AI_ML_SurvivalGuide/blob/main/4_Clustering/K-Means/K_Means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # K-Means Algo
# ***
# this algorithem is used to group data into classes or clusters.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans

# %%
iris = load_iris()
x = iris.data

k = 3
km = KMeans(n_clusters = k)
km.fit(x)

# %%
centers = km.cluster_centers_
labels = km.labels_

# Use PCA to reduce dimensions for visualization
pca = PCA(n_components=2)
X_reduced = pca.fit_transform(x)

# Plot the clusters
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=labels, cmap='viridis')
plt.scatter(pca.transform(centers)[:, 0], pca.transform(centers)[:, 1], c='red', s=200, alpha=0.75, marker='x')
plt.title('K-means Clustering on Iris Dataset')
plt.xlabel('PCA Feature 1')
plt.ylabel('PCA Feature 2')
plt.show()
